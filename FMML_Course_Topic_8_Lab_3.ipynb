# %% [markdown]
# <a href="https://colab.research.google.com/github/ebrahim-15/FMML_stu/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 14:06:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   214MB/s    in 0.3s
#
# 2024-04-02 14:06:20 (214 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 38499  cs/0703088v1  <PLOT > is a collection of routines to draw su...    cs
# 17118  1708.06510v1  Homographs, words with different meanings but ...    cs
# 21250  1711.04309v2  Here we examine the paperclip apocalypse conce...    cs
# 6248   1610.04420v4  Domain adaptation (DA) is an important and eme...  stat
# 39412  1603.00150v1  Gaussian mixture alignment is a family of appr...    cs
# ...             ...                                                ...   ...
# 25078  1504.06055v1  Several benchmark datasets for visual tracking...    cs
# 40410   1004.1743v1  Clustering is an unsupervised learning method ...    cs
# 7406   1712.05556v1  We propose a method to optimise the parameters...  stat
# 6418   1701.05573v1  We introduce a new dynamical system for sequen...  stat
# 18677   1108.5250v1  A brain-computer interface (BCI) may be used t...    cs
#
#                                                    title  year  \
# 38499                       Plot 94 in ambiance X-Window  2007
# 17118  Handling Homographs in Neural Machine Translation  2017
# 21250    Self-Regulating Artificial General Intelligence  2017
# 6248   Theoretical Analysis of Domain Adaptation with...  2016
# 39412  GOGMA: Globally-Optimal Gaussian Mixture Align...  2016
# ...                                                  ...   ...
# 25078  Understanding and Diagnosing Visual Tracking S...  2015
# 40410  An Analytical Study on Behavior of Clusters Us...  2010
# 7406     Safe Policy Search with Gaussian Process Models  2017
# 6418                    Poisson--Gamma Dynamical Systems  2017
# 18677  Single-trial EEG Discrimination between Wrist ...  2011
#
#                                                 keywords
# 38499  [collection, presenting, functions, operative,...
# 17118  [homographs, different, difficulty, translatio...
# 21250  [paperclip, apocalypse, artificial, intelligen...
# 6248   [adaptation, important, occurring, distributio...
# 39412  [alignment, approaches, frequently, registrati...
# ...                                                  ...
# 25078  [benchmark, usefulness, sufficient, understand...
# 40410  [clustering, unsupervised, constitutes, corner...
# 7406   [parameters, efficient, framework, properties,...
# 6418   [introduce, dynamical, sequentially, multivari...
# 18677  [interface, prosthetic, sensorimotor, interpre...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 38499    [collection, presenting, functions, operative,...
# 17118    [homographs, different, difficulty, translatio...
# 21250    [paperclip, apocalypse, artificial, intelligen...
# 6248     [adaptation, important, occurring, distributio...
# 39412    [alignment, approaches, frequently, registrati...
#                                ...
# 36021    [contention, challenging, switching, contentio...
# 21229    [vagueness, uncertainty, management, challenge...
# 3345     [ambiguity, classification, difficult, discrim...
# 22685    [factorisation, decompose, multivariate, obser...
# 9036     [investigated, possibility, conjunction, comme...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8725 words.
# Out of those 4601 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fdadcf1b-1ef6-4348-849e-b7461c4e71e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdadcf1b-1ef6-4348-849e-b7461c4e71e6")) {                    Plotly.newPlot(                        "fdadcf1b-1ef6-4348-849e-b7461c4e71e6",                        [{"x":["investigation","functions","institute","collection","presenting","calculation","differentiate","alleviated","literature","difficult","difficulty","different","demonstrate","hypothesize","significant","theoretically","empirical","ambiguous","translating","performance","sentential","disambiguation","embeddings","translation","experiments","unavailable","accumulates","intelligence","resources","architectures","developed","developments","superintelligent","regulating","recursive","artificial","conditions","improvement","capabilities","producing","probability","distributions","occurring","minimizing","particular","theoretical","transport","adaptation","combining","divergence","generalization","algorithms","transportation","unsupervised","frameworks","important","efficiency","advantages","wasserstein","guarantees","algorithm","performed","guaranteeing","consequently","empirically","accelerate","objective","regardless","registration","optimisation","approaches","frequently","alignment","initialisation","evaluation","dependent","optimality","guarantee","convergence","supported","integrated","challenging","susceptible","consuming","segmentation","automatic","efficient","radiation","measurement","necessary","resonance","experience","detection","diagnostic","operators","promising","challenge","determination","multimodal","convolutional","efficiently","noninvasive","treatment","technique","evaluated","quantitative","validation","structure","structured","regression","structural","hierarchical","assumptions","modelling","expectation","coefficients","propagation","inference","incorporates","dimensional","collections","introduce","treatments","experiment","techniques","bureaucratic","identification","inferences","estimating","interventions","inductively","representation","immigration","attitudes","foundation","conceptual","framework","researchers","discovered","computationally","implementation","construct","incrementally","motivates","networked","perceptron","quadratic","prediction","similarity","construction","arbitrary","infeasible","logarithmic","initially","motivated","fundamentally","conventional","superposition","experimentally","tightness","optimization","observations","observation","contaminated","fundamental","applications","associated","measurements","constrained","modalities","distributed","statistics","parameters","marketing","likelihood","identically","complexity","tractable","sometimes","generalize","counterfactuals","counterfactual","unreliable","predicting","reasoning","sensitive","continuous","practitioners","predictive","progression","trajectories","sequences","dangerous","relationships","supervised","individualized","partitioning","exploited","optimizations","approximations"],"y":[25,215,7,81,15,20,5,2,134,139,38,728,526,6,247,56,171,24,12,865,5,18,82,103,586,8,1,82,63,105,205,26,4,2,27,137,139,132,45,27,160,117,11,40,273,163,8,61,102,31,124,604,13,141,33,335,155,79,11,77,839,123,6,36,77,23,177,8,33,18,434,33,50,2,265,82,26,47,143,16,67,275,6,34,209,172,415,6,28,70,16,41,346,18,47,123,151,12,32,379,161,2,36,226,154,63,53,337,89,110,62,105,70,54,28,37,76,219,37,172,14,324,7,66,376,1,89,12,59,10,2,401,0,2,14,17,560,74,18,89,135,94,20,14,4,21,35,207,160,72,93,12,27,20,51,5,100,3,63,1,296,65,59,5,74,419,98,57,72,31,104,60,241,8,64,4,226,21,21,63,2,5,11,65,144,65,98,7,53,10,21,95,2,72,197,1,21,37,5,34],"type":"bar"},{"x":["investigation","functions","institute","collec ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4601,), (4601, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Misfire</span> <span style='background-color:rgba(0, 255, 0, 0.5377777777777778);'>Detection</span> <span style=''>in</span> <span style=''>IC</span> <span style=''>Engine</span> <span style=''>using</span> <span style=''>Kstar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>Misfire</span> <span style=''>in</span> <span style=''>an</span> <span style=''>IC</span> <span style=''>Engine</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>continues</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>reduced</span> <span style=''>fuel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>increased</span> <span style=''>power</span> <span style=''>loss</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>emissions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>containing</span> <span style=''>heavy</span> <span style='background-color:rgba(255, 0, 0, 0.4054054054054053);'>concentration</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hydrocarbons</span> <span style=''>Misfiring</span> <span style=''>creates</span> <span style=''>a</span> <span style=''>unique</span> <span style=''>vibration</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attributed</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>cylinder</span> <span style=''>Useful</span> <span style=''>features</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.6911764705882353);'>extracted</span> <span style=''>from</span> <span style=''>these</span> <span style=''>patterns</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>analyzed</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>misfire</span> <span style='background-color:rgba(255, 0, 0, 0.3032258064516129);'>Statistical</span> <span style=''>features</span> <span style=''>from</span> <span style=''>these</span> <span style=''>vibration</span> <span style=''>signals</span> <span style=''>were</span> <span style='background-color:rgba(0, 255, 0, 0.6911764705882353);'>extracted</span> <span style=''>Out</span> <span style=''>of</span> <span style=''>these</span> <span style=''>useful</span> <span style=''>features</span> <span style=''>were</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identified</span> <span style=''>using</span> <span style=''>the</span> <span style=''>J48</span> <span style=''>decision</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>selected</span> <span style=''>features</span> <span style=''>were</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>using</span> <span style=''>the</span> <span style=''>Kstar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>Kstar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3460076045627376);'>presented</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Churn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>in</span> <span style=''>Mobile</span> <span style=''>Social</span> <span style=''>Games</span> <span style=''>Towards</span> <span style=''>a</span> <span style=''>Complete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Assessment</span> <span style=''>Using</span> <span style=''>Survival</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Ensembles</span> <br/><br/><span style=''>Reducing</span> <span style=''>user</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attrition</span> <span style=''>ie</span> <span style=''>churn</span> <span style=''>is</span> <span style=''>a</span> <span style=''>broad</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>faced</span> <span style=''>by</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>industries</span> <span style=''>In</span> <span style=''>mobile</span> <span style=''>social</span> <span style=''>games</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decreasing</span> <span style=''>churn</span> <span style=''>is</span> <span style=''>decisive</span> <span style=''>to</span> <span style=''>increase</span> <span style=''>player</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>retention</span> <span style=''>and</span> <span style=''>rise</span> <span style=''>revenues</span> <span style=''>Churn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>allow</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>player</span> <span style=''>loyalty</span> <span style=''>and</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anticipate</span> <span style=''>when</span> <span style=''>they</span> <span style=''>will</span> <span style=''>stop</span> <span style=''>playing</span> <span style=''>a</span> <span style=''>game</span> <span style=''>Thanks</span> <span style=''>to</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initiatives</span> <span style=''>can</span> <span style=''>be</span> <span style=''>taken</span> <span style=''>to</span> <span style=''>retain</span> <span style=''>those</span> <span style=''>players</span> <span style=''>who</span> <span style=''>are</span> <span style=''>more</span> <span style=''>likely</span> <span style=''>to</span> <span style=''>churn</span> <span style=''>Survival</span> <span style=''>analysis</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>time</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>event</span> <span style=''>churn</span> <span style=''>in</span> <span style=''>our</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classical</span> <span style=''>methods</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <span style=''>could</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>only</span> <span style=''>when</span> <span style=''>all</span> <span style=''>players</span> <span style=''>have</span> <span style=''>left</span> <span style=''>the</span> <span style=''>game</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>arises</span> <span style=''>for</span> <span style=''>datasets</span> <span style=''>with</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dynamic</span> <span style=''>Pricing</span> <span style=''>under</span> <span style=''>Finite</span> <span style=''>Space</span> <span style=''>Demand</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uncertainty</span> <span style=''>A</span> <span style=''>Multi</span> <span style=''>Armed</span> <span style=''>Bandit</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependent</span> <span style=''>Arms</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>dynamic</span> <span style=''>pricing</span> <span style=''>problem</span> <span style=''>under</span> <span style=''>unknown</span> <span style=''>demand</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>a</span> <span style=''>seller</span> <span style=''>offers</span> <span style=''>prices</span> <span style=''>to</span> <span style=''>a</span> <span style=''>stream</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>customers</span> <span style=''>and</span> <span style=''>observes</span> <span style=''>either</span> <span style=''>success</span> <span style=''>or</span> <span style=''>failure</span> <span style=''>in</span> <span style=''>each</span> <span style=''>sale</span> <span style=''>attempt</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>demand</span> <span style=''>model</span> <span style=''>is</span> <span style=''>unknown</span> <span style=''>to</span> <span style=''>the</span> <span style=''>seller</span> <span style=''>and</span> <span style=''>can</span> <span style=''>take</span> <span style=''>one</span> <span style=''>of</span> <span style=''>N</span> <span style=''>possible</span> <span style=''>forms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulated</span> <span style=''>as</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>arms</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>dynamic</span> <span style=''>pricing</span> <span style=''>policy</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.49606299212598426);'>likelihood</span> <span style=''>ratio</span> <span style=''>test</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>policy</span> <span style=''>achieves</span> <span style=''>complete</span> <span style=''>learning</span> <span style=''>ie</span> <span style=''>it</span> <span style=''>offers</span> <span style=''>a</span> <span style=''>bounded</span> <span style=''>regret</span> <span style=''>where</span> <span style=''>regret</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style=''>revenue</span> <span style=''>loss</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>case</span> <span style=''>with</span> <span style=''>a</span> <span style=''>known</span> <span style=''>demand</span> <span style=''>model</span> <span style=''>This</span> <span style=''>is</span> <span style=''>in</span> <span style=''>sharp</span> <span style=''>contrast</span> <span style=''>with</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>review</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>commentary</span> <span style=''>on</span> <span style=''>the</span> <span style=''>past</span> <span style=''>present</span> <span style=''>and</span> <span style=''>future</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>Through</span> <span style=''>case</span> <span style=''>studies</span> <span style=''>on</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>the</span> <span style=''>training</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>what</span> <span style=''>makes</span> <span style=''>them</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>A</span> <span style=''>major</span> <span style=''>theme</span> <span style=''>of</span> <span style=''>our</span> <span style=''>study</span> <span style=''>is</span> <span style=''>that</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinctive</span> <span style=''>setting</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>(SG)</span> <span style=''>method</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditionally</span> <span style=''>played</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>falter</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprehensive</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>yet</span> <span style='background-color:rgba(0, 255, 0, 0.3) ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09793447293447294)
# 	processing (0.10113960113960115)
# 	representation (0.14280626780626782)
# 	segmentation (0.07443019943019943)
# 	knowledge (0.13212250712250712)
# 	information (0.2532051282051282)
# 	detection (0.12321937321937322)
# 	different (0.25925925925925924)
# 	convolutional (0.13497150997150997)
# 	recognition (0.13212250712250712)
#
# Some Statistics words are:
# 	algorithm (0.38353413654618473)
# 	theoretical (0.14708835341365462)
# 	stochastic (0.13855421686746988)
# 	statistical (0.15210843373493976)
# 	variables (0.14357429718875503)
# 	distribution (0.19477911646586346)
# 	estimation (0.18323293172690763)
# 	dimensional (0.1857429718875502)
# 	inference (0.20783132530120482)
# 	regression (0.18072289156626506)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2126bc91-f57d-45c6-8478-59af93d43553" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2126bc91-f57d-45c6-8478-59af93d43553")) {                    Plotly.newPlot(                        "2126bc91-f57d-45c6-8478-59af93d43553",                        [{"x":["investigation","functions","institute","collection","presenting","calculation","differentiate","alleviated","literature","difficult","difficulty","different","demonstrate","hypothesize","significant","theoretically","empirical","ambiguous","translating","performance","sentential","disambiguation","embeddings","translation","experiments","unavailable","accumulates","intelligence","resources","architectures","developed","developments","superintelligent","regulating","recursive","artificial","conditions","improvement","capabilities","producing","probability","distributions","occurring","minimizing","particular","theoretical","transport","adaptation","combining","divergence","generalization","algorithms","transportation","unsupervised","frameworks","important","efficiency","advantages","wasserstein","guarantees","algorithm","performed","guaranteeing","consequently","empirically","accelerate","objective","regardless","registration","optimisation","approaches","frequently","alignment","initialisation","evaluation","dependent","optimality","guarantee","convergence","supported","integrated","challenging","susceptible","consuming","segmentation","automatic","efficient","radiation","measurement","necessary","resonance","experience","detection","diagnostic","operators","promising","challenge","determination","multimodal","convolutional","efficiently","noninvasive","treatment","technique","evaluated","quantitative","validation","structure","structured","regression","structural","hierarchical","assumptions","modelling","expectation","coefficients","propagation","inference","incorporates","dimensional","collections","introduce","treatments","experiment","techniques","bureaucratic","identification","inferences","estimating","interventions","inductively","representation","immigration","attitudes","foundation","conceptual","framework","researchers","discovered","computationally","implementation","construct","incrementally","motivates","networked","perceptron","quadratic","prediction","similarity","construction","arbitrary","infeasible","logarithmic","initially","motivated","fundamentally","conventional","superposition","experimentally","tightness","optimization","observations","observation","contaminated","fundamental","applications","associated","measurements","constrained","modalities","distributed","statistics","parameters","marketing","likelihood","identically","complexity","tractable","sometimes","generalize","counterfactuals","counterfactual","unreliable","predicting","reasoning","sensitive","continuous","practitioners","predictive","progression","trajectories","sequences","dangerous","relationships","supervised","individualized","partitioning","exploited","optimizations","approximations","eliminated","separable","increased","illumination","variations","convolved","information","computational","expression","generated","classifiers","clustering","embedding","prototypes","recognition","unimportant","stationary","convergent","consistently","regularized","coordinate","stochastic","formulation","consisting","numerically","identical","bootstrap","independent","traditional","establish","covariance","estimator","unexplored","estimates","estimators","convenience","applicable","estimation","generalized","perturbed","resampling","numerical","parameter","increasing","popularity","implement","procedure","asymptotic","properties","established","repeatedly","statistical","involving","inferent ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	immigration
# 	pessimistic
# 	adjustments
# 	diffeomorphisms
# 	trilinear
# 	commutative
# 	unattainable
# 	emphdirectly
# 	initialising
# 	suboptimality
# 	dendrogram
# 	covariates
# 	misspecified
# 	submanifold
# 	changepoint
# 	integrands
# 	repulsive
# 	maximized
# 	prognostics
# 	dependences
# Some words which never appear in Statistics papers:
# 	hypothesize
# 	sentential
# 	disambiguation
# 	superintelligent
# 	unimportant
# 	initiated
# 	presently
# 	cryptographic
# 	halfspaces
# 	trustworthy
# 	completes
# 	circulating
# 	involvement
# 	functionality
# 	coalition
# 	segmenter
# 	discourse
# 	utilities
# 	unsatisfiable
# 	curriculum

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059881888559102e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
